# %%
# %pip install pennylane
# %pip install kagglehub
# %pip install monai
# %pip install ipywidgets
# %pip install pillow tensorflow scikit-learn
# %pip install opencv-python 
# %pip install torchvision
# %pip install matplotlib
# Out:
# Requirement already satisfied: pennylane in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (0.39.0)
# Requirement already satisfied: numpy<2.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (1.14.1)
# Requirement already satisfied: networkx in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (3.4.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (0.15.1)
# Requirement already satisfied: autograd in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (1.7.0)
# Requirement already satisfied: toml in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (0.7.0)
# Requirement already satisfied: cachetools in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (5.5.0)
# Requirement already satisfied: pennylane-lightning>=0.39 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (0.39.0)
# Requirement already satisfied: requests in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from pennylane) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->pennylane) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->pennylane) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->pennylane) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kagglehub in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (0.3.4)
# Requirement already satisfied: packaging in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: monai in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.24 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from monai) (1.26.4)
# Requirement already satisfied: torch>=1.9 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from monai) (2.5.1)
# Requirement already satisfied: filelock in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: networkx in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch>=1.9->monai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from sympy==1.13.1->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from jinja2->torch>=1.9->monai) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (11.0.0)
# Requirement already satisfied: tensorflow in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (2.18.0)
# Requirement already satisfied: scikit-learn in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (1.5.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (0.20.1)
# Requirement already satisfied: numpy in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\maja1\anaconda3\envs\tumor\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np

from PIL import Image
import cv2
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from monai.transforms import ScaleIntensity
import kagglehub

# %% [markdown]
# Download latest version https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection/data

# %%
path = kagglehub.dataset_download(r"navoneel/brain-mri-images-for-brain-tumor-detection")
# print("Path to dataset files:", path)

# %% [markdown]
# Paths

# %%
dataset_path = f'{path}/brain_tumor_dataset/'
validation_path_yes = f'{path}/yes'
validation_path_no = f'{path}/no'

# %% [markdown]
# Check data

# %%
mri_image = cv2.imread(f'{dataset_path}yes/Y1.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(mri_image, cmap='gray')
